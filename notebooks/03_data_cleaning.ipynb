# %% [markdown]
# # Smart Recommendation & Personalization Engine
# ## Data Cleaning and Preprocessing Pipeline
#
# In this notebook, we perform professional data cleaning and preprocessing on the RetailRocket e-commerce dataset.
#
# The primary objective of this notebook is to:
#
# - Clean raw transactional data
# - Handle missing values and duplicate records
# - Convert timestamps into readable datetime format
# - Standardize dataset structure
# - Prepare high-quality data for downstream machine learning tasks
# - Improve data consistency and reliability
#
# This notebook strictly focuses on preprocessing and data cleaning operations following industry-standard machine learning practices and modular project architecture.
#
# The cleaned datasets generated from this notebook will be used in subsequent stages such as:
#
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Recommendation System Development
# - Personalization Modeling

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load events dataset
events_df = pd.read_csv('../data/raw/events.csv')

# Load item properties datasets
item_properties_part1 = pd.read_csv('../data/raw/item_properties_part1.csv')
item_properties_part2 = pd.read_csv('../data/raw/item_properties_part2.csv')

# Load category tree dataset
category_tree_df = pd.read_csv('../data/raw/category_tree.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Load events dataset
# ----> 2 events_df = pd.read_csv('../data/raw/events.csv')
#       4 # Load item properties datasets
#       5 item_properties_part1 = pd.read_csv('../data/raw/item_properties_part1.csv')
#
# ...

# %%
print('Events Dataset Shape:', events_df.shape)
print('\n')

events_df.sample(5)

# %%
events_df.info()

# %%
events_df.describe(include='all')

# %%
# Missing values percentage
missing_values = pd.DataFrame({
    'Missing Count': events_df.isnull().sum(),
    'Missing Percentage': (events_df.isnull().sum() / len(events_df)) * 100
})

missing_values.sort_values(by='Missing Percentage', ascending=False)

# %%
# Check duplicate rows
duplicate_count = events_df.duplicated().sum()

print(f'Total Duplicate Rows: {duplicate_count}')

# %%
# Remove duplicate records
events_df.drop_duplicates(inplace=True)

print('Shape After Removing Duplicates:', events_df.shape)

# %%
# Convert timestamp column
events_df['datetime'] = pd.to_datetime(events_df['timestamp'], unit='ms')

# Extract useful date features
events_df['date'] = events_df['datetime'].dt.date
events_df['year'] = events_df['datetime'].dt.year
events_df['month'] = events_df['datetime'].dt.month
events_df['day'] = events_df['datetime'].dt.day
events_df['hour'] = events_df['datetime'].dt.hour

# %%
#verifying
events_df[['timestamp', 'datetime']].head()

# %% [markdown]
# # 8. Validate Event Column Consistency

# %%
# Validate event column consistency
events_df["event"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Validate event column consistency
# ----> 2 events_df["event"].value_counts()
#
# NameError: name 'events_df' is not defined
